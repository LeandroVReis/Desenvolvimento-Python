# %% [markdown]
# # Exercício - Mini Projeto de Análise de Dados
#
# Vamos fazer um exercício completo de pandas para um miniprojeto de análise de dados.
#
# Esse exercício vai obrigar a gente a usar boa parte dos conhecimento de pandas e até de outros módulos que já aprendemos ao longo do curso.
#
# ### O que temos?
#
# Temos os dados de 2019 de uma empresa de prestação de serviços.
#
# - CadastroFuncionarios
# - CadastroClientes
# - BaseServiçosPrestados
#
# Obs1: Para ler arquivos csv, temos o read_csv<br>
# Obs2: Para ler arquivos xlsx (arquivos em excel normais, que não são padrão csv), temos o read_excel
#
# ### O que queremos saber/fazer?
#
# 1. Valor Total da Folha Salarial -> Qual foi o gasto total com salários de funcionários pela empresa? <br>
#     Sugestão: calcule o salário total de cada funcionário, salário + benefícios + impostos, depois some todos os salários
#
#
# 2. Qual foi o faturamento da empresa?<br>
#     Sugestão: calcule o faturamento total de cada serviço e depois some o faturamento de todos
#
#
# 3. Qual o % de funcionários que já fechou algum contrato?<br>
#     Sugestão: na base de serviços temos o funcionário que fechou cada serviço. Mas nem todos os funcionários que a empresa tem já fecharam algum serviço.<br>
#     . Na base de funcionários temos uma lista com todos os funcionários<br>
#     . Queremos calcular Qtde_Funcionarios_Fecharam_Serviço / Qtde_Funcionários_Totais<br>
#     . Para calcular a qtde de funcionários que fecharam algum serviço, use a base de serviços e conte quantos funcionários tem ali. Mas lembre-se, cada funcionário só pode ser contado uma única vez.<br><br>
#     Dica: se você aplicar o método .unique() em uma variável que é apenas 1 coluna de um dataframe, ele vai excluir todos os valores duplicados daquela coluna.<br>
#     Ex: unicos_colunaA = dataframe['colunaA'].unique() te dá como resposta uma lista com todos os itens da colunaA aparecendo uma única vez. Todos os valores repetidos da colunaA são excluidos da variável unicos_colunaA
#
#
# 4. Calcule o total de contratos que cada área da empresa já fechou
#
#
# 5. Calcule o total de funcionários por área
#
#
# 6. Qual o ticket médio mensal (faturamento médio mensal) dos contratos?<br>
#     Dica: .mean() calcula a média -> exemplo: media_colunaA = dataframe['colunaA'].mean()
#
# Obs: Lembrando as opções mais usuais de encoding:<br>
# encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'
#
# Observação Importante: Se o seu código der um erro na hora de importar os arquivos:<br>
# - CadastroClientes.csv
# - CadastroFuncionarios.csv
#
# Use separador ";" (ponto e vírgula) para resolver

# %%
import pandas as pd

funcionarios_df = pd.read_csv(r'CadastroFuncionarios.csv', sep=';', decimal= ',')
clientes_df = pd.read_csv(r'CadastroClientes.csv', sep=';', decimal = ',')
serv_prest_df = pd.read_excel(r'BaseServiçosPrestados.xlsx',decimal = ',')

# %% [markdown]
# 1. Valor Total da Folha Salarial -> Qual foi o gasto total com salários de funcionários pela empresa? Sugestão: calcule o salário total de cada funcionário, salário + benefícios + impostos, depois some todos os salários

# %%
display(funcionarios_df)
# Out:
#      ID Funcionário Estado Civil           Nome Completo  Salario Base  \
# 0                 1            C        Gabriel Mesquita         21910
# 1                 2            C             João Haddad          5404
# 2                 3            C  Amanda Marques Ribeiro         16066
# 3                 4            C         Guilherme Nunez         21305
# 4                 5            C           Adelino Gomes          5098
# ..              ...          ...                     ...           ...
# 109             143            C   Renan Scharnhorst Ott         10793
# 110             144            S      Lucas Brum Pereira          4048
# 111             148            S            Caio Stellet         24596
# 112             149            C          Fernanda Rocha          5078
# 113             150            C            Eduardo Brum         15939
#
#      Impostos  Beneficios   VT      VR       Cargo            Area
# ...

# %%
qtd_tot_salbase = funcionarios_df['Salario Base'].sum()
qtd_tot_impostos = funcionarios_df['Impostos'].sum()
qtd_tot_benef = funcionarios_df['Beneficios'].sum()
gasto_total = qtd_tot_salbase + qtd_tot_impostos + qtd_tot_benef
texto = 'Gasto total é R$ {:_.2f}'.format(gasto_total)
texto = texto.replace('.',',').replace('_','.')
print(texto)
# Out:
# Gasto total é R$ 2.614.343,30

# %% [markdown]
# 2. Qual foi o faturamento da empresa? Sugestão: calcule o faturamento total de cada serviço e depois some o faturamento de todos

# %%
cli_simp_df = clientes_df[['ID Cliente','Valor Contrato Mensal']]
faturamento_df = serv_prest_df.merge(cli_simp_df, on = 'ID Cliente')
faturamento_df['Valor Total Contrato'] = faturamento_df['Tempo Total de Contrato (Meses)'] * faturamento_df['Valor Contrato Mensal']
func_simp_df = funcionarios_df[['ID Funcionário','Area']]
faturamento_df = faturamento_df.merge(func_simp_df, on = 'ID Funcionário')
display(faturamento_df)
# Out:
#     Codigo do Servico  ID Funcionário  ID Cliente  \
# 0              OS0001              67           1
# 1              OS0058              67          78
# 2              OS0092              67         125
# 3              OS0128              67         175
# 4              OS0002              17           2
# ..                ...             ...         ...
# 232            OS0224              25         304
# 233            OS0228              79         308
# 234            OS0229              99         309
# 235            OS0230              14         310
# 236            OS0235              72         317
#
#      Tempo Total de Contrato (Meses)  Valor Contrato Mensal  \
# 0                                 14                    540
# 1                                  6                   1710
# 2                                  8                   1710
# 3                                  6                    945
# ...

# %%
faturamento_tot = faturamento_df['Valor Total Contrato'].sum()
texto = 'Faturamento total foi R$ {:_.2f}'.format(faturamento_tot)
texto = texto.replace('.',',').replace('_','.')
print(texto)
# Out:
# Faturamento total foi R$ 5.519.160,00

# %% [markdown]
# 3. Qual o % de funcionários que já fechou algum contrato?
# Sugestão: na base de serviços temos o funcionário que fechou cada serviço. Mas nem todos os funcionários que a empresa tem já fecharam algum serviço.
# . Na base de funcionários temos uma lista com todos os funcionários
# . Queremos calcular Qtde_Funcionarios_Fecharam_Serviço / Qtde_Funcionários_Totais
# . Para calcular a qtde de funcionários que fecharam algum serviço, use a base de serviços e conte quantos funcionários tem ali. Mas lembre-se, cada funcionário só pode ser contado uma única vez.
#
#     Dica: se você aplicar o método .unique() em uma variável que é apenas 1 coluna de um dataframe, ele vai excluir todos os valores duplicados daquela coluna.<br>
#     Ex: unicos_colunaA = dataframe['colunaA'].unique() te dá como resposta uma lista com todos os itens da colunaA aparecendo uma única vez. Todos os valores repetidos da colunaA são excluidos da variável unicos_colunaA

# %%
qtd_tot_func = len(funcionarios_df['ID Funcionário'])
qtd_func_comfat = len(faturamento_df['ID Funcionário'].unique())
qtd_tot_func = len(funcionarios_df['ID Funcionário'])
print('Total de Funcionários: {}\nFuncionários que fecharam contratos: {}\nRendimento dos funcionários: {:.2%}'.format(qtd_tot_func,qtd_func_comfat,qtd_func_comfat/qtd_tot_func))
# Out:
# 114
# Total de Funcionários: 114
# Funcionários que fecharam contratos: 99
# Rendimento dos funcionários: 86.84%

# %% [markdown]
# 4. Calcule o total de contratos que cada área da empresa já fechou

# %%
qtd_contratos_area = faturamento_df['Area'].value_counts()
display(qtd_contratos_area)
# Out:
# Administrativo    63
# Operações         48
# Comercial         44
# Financeiro        42
# Logística         40
# Name: Area, dtype: int64

# %% [markdown]
# 5. Calcule o total de funcionários por área

# %%
qtd_func_area = funcionarios_df['Area'].value_counts()
display(qtd_func_area)
# Out:
# Administrativo    26
# Comercial         26
# Operações         23
# Logística         21
# Financeiro        18
# Name: Area, dtype: int64

# %% [markdown]
# 6. Qual o ticket médio mensal (faturamento médio mensal) dos contratos?<br>
#     Dica: .mean() calcula a média -> exemplo: media_colunaA = dataframe['colunaA'].mean()

# %%
media_val_mensal_cont = clientes_df['Valor Contrato Mensal'].mean()
media_qtd_meses_cont = serv_prest_df['Tempo Total de Contrato (Meses)'].mean()
print('{:.2f} | {:.2f}'.format(media_val_mensal_cont,media_qtd_meses_cont))
media_fat_mensal = media_val_mensal_cont * media_qtd_meses_cont
texto = 'Faturamento médio mensal é R$ {:_.2f}'.format(media_fat_mensal)
texto = texto.replace('.',',').replace('_','.')
print(texto)
# Out:
# 2502.56 | 9.65
# Faturamento médio mensal é R$ 24.159,76
